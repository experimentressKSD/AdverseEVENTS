# %% [markdown]
# ## RESPI FAILURE

# %%
import matplotlib.pyplot as plt


# respi sliding windows

AUPRC_values_LSTM  =[0.4959, 0.5156, 0.5307, 0.5497]
AUPRC_values_TCN  =[0.4738, 0.503, 0.5296, 0.5676]
AUPRC_values_LSTM_enc_dec  =[0.4829, 0.5086, 0.5413, 0.5695]
AUPRC_values_LSTM_enc_dec_attn  =[0.5316, 0.5464, 0.5658, 0.5884]

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# X-axis values
K_values = [6, 12, 24, 48]

# Plot data
ax.plot(K_values, AUPRC_values_LSTM, label='LSTM', linestyle='--', marker='x')
ax.plot(K_values, AUPRC_values_TCN, label='TCN', linestyle='--', marker='x')
ax.plot(K_values, AUPRC_values_LSTM_enc_dec, label='LSTM Enc-Dec', linestyle='--', marker='x')
ax.plot(K_values, AUPRC_values_LSTM_enc_dec_attn, label='LSTM Enc-Dec Attn', linestyle='--', marker='x')


plt.xticks(K_values)

# Add legend
ax.legend()

# Set x-label and y-label
plt.xlabel('K value (K = 1 represents 5 minutes)')
plt.ylabel('AUPRC')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
AUROC_values_LSTM = [0.3455, 0.368, 0.3915, 0.419]
AUROC_values_TCN = [0.3442, 0.375, 0.4084, 0.4532]
AUROC_values_LSTM_enc_dec = [0.3538, 0.379, 0.4211, 0.4596]
AUROC_values_LSTM_enc_dec_attn = [0.3767, 0.4018, 0.4283, 0.4585]

# X-axis values
K_values = [6, 12, 24, 48]

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot data
ax.plot(K_values, AUROC_values_LSTM, label='LSTM', linestyle='--', marker='x')
ax.plot(K_values, AUROC_values_TCN, label='TCN', linestyle='--', marker='x')
ax.plot(K_values, AUROC_values_LSTM_enc_dec, label='LSTM Enc-Dec', linestyle='--', marker='x')
ax.plot(K_values, AUROC_values_LSTM_enc_dec_attn, label='LSTM Enc-Dec Attn', linestyle='--', marker='x')

# Set x-ticks
plt.xticks(K_values)

# Set x-label and y-label
plt.xlabel('K value, 5 mins sampling')
plt.ylabel('AUROC')

# Add legend
ax.legend()

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
precision = [0.5556, 0.5427, 0.5715, 0.568]
specificity = [0.5969, 0.7685, 0.665, 0.812]
sensitivity = [0.34, 0.104, 0.254, 0.077]

# X-axis values
models = ['LSTM_enc_dec, K = 48', 'LSTM_enc_dec, K = 24', 'LSTM_enc_dec_attn, K = 48', 'LSTM_enc_dec_attn, K = 24']
x = np.arange(len(models))  # the label locations

# Width of the bars
width = 0.2

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Add bars
rects1 = ax.bar(x - width, precision, width, label='Precision')
rects2 = ax.bar(x, specificity, width, label='Specificity')
rects3 = ax.bar(x + width, sensitivity, width, label='Sensitivity')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Models')
ax.set_ylabel('Scores')
ax.set_title('Classification scores by model at cls. threshold = 0.5')
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=45)
ax.legend()

# Show plot
plt.show()

# %% [markdown]
# ## CIRC FAILURE

# %%
import matplotlib.pyplot as plt


# circ sliding windows

AUPRC_values_LSTM  =[0.07677, 0.0966, 0.196, 0.1948]
AUPRC_values_TCN  =[0.1339, 0.16, 0.1887, 0.2336]
AUPRC_values_LSTM_enc_dec_attn  =[0.1391, 0.1615, 0.1944, 0.2326]
AUPRC_values_LSTM_enc_dec  =[0.144, 0.1647, 0.1964, 0.2308]

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# X-axis values
K_values = [6, 12, 24, 48]

# Plot data
ax.plot(K_values, AUPRC_values_LSTM, label='LSTM', linestyle='--', marker='x')
ax.plot(K_values, AUPRC_values_TCN, label='TCN', linestyle='--', marker='x')
ax.plot(K_values, AUPRC_values_LSTM_enc_dec, label='LSTM Enc-Dec', linestyle='--', marker='x')
ax.plot(K_values, AUPRC_values_LSTM_enc_dec_attn, label='LSTM Enc-Dec Attn', linestyle='--', marker='x')


plt.xticks(K_values)

# Add legend
ax.legend()

# Set x-label and y-label
plt.xlabel('K value (K = 1 represents 5 minutes)')
plt.ylabel('AUPRC')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
AUROC_values_LSTM = [0.2799, 0.365, 0.4738, 0.573]
AUROC_values_TCN = [0.4109, 0.473, 0.535, 0.5967]
AUROC_values_LSTM_enc_dec_attn = [0.4509, 0.4957, 0.5486, 0.597]
AUROC_values_LSTM_enc_dec = [0.432, 0.483, 0.5483, 0.5964]

# X-axis values
K_values = [6, 12, 24, 48]

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot data
ax.plot(K_values, AUROC_values_LSTM, label='LSTM', linestyle='--', marker='x')
ax.plot(K_values, AUROC_values_TCN, label='TCN', linestyle='--', marker='x')
ax.plot(K_values, AUROC_values_LSTM_enc_dec, label='LSTM Enc-Dec', linestyle='--', marker='x')
ax.plot(K_values, AUROC_values_LSTM_enc_dec_attn, label='LSTM Enc-Dec Attn', linestyle='--', marker='x')

# Set x-ticks
plt.xticks(K_values)

# Set x-label and y-label
plt.xlabel('K value, 5 mins sampling')
plt.ylabel('AUROC')

# Add legend
ax.legend()

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
precision = [0.209, 0.18, 0.2174, 0.1923]
specificity = [0.6267, 0.785, 0.6366, 0.793]
sensitivity = [0.5, 0.255, 0.499, 0.2722]

# X-axis values
models = ['LSTM_enc_dec_attn, K = 48', 'LSTM_enc_dec_attn, K = 24', 'LSTM_enc_dec, K = 48', 'LSTM_enc_dec, K = 24']
x = np.arange(len(models))  # the label locations

# Width of the bars
width = 0.2

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Add bars
rects1 = ax.bar(x - width, precision, width, label='Precision')
rects2 = ax.bar(x, specificity, width, label='Specificity')
rects3 = ax.bar(x + width, sensitivity, width, label='Sensitivity')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Models')
ax.set_ylabel('Scores')
ax.set_title('Classification scores by model at cls. threshold = 0.5')
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=45)
ax.legend()

# Show plot
plt.show()

# %% [markdown]
# ## KIDNEY FAILURE

# %%
import matplotlib.pyplot as plt


# circ sliding windows

AUPRC_values_TCN  =[0.411, 0.4243, 0.44, 0.4568]
AUPRC_values_LSTM  =[0.4296, 0.4395, 0.4484, 0.459]
AUPRC_values_LSTM_enc_dec_attn  = [0.4511, 0.46,  0.4665, 0.4738]
AUPRC_values_LSTM_enc_dec  =[0.4421, 0.4469, 0.4522, 0.4617]

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# X-axis values
K_values = [6, 12, 24, 48]

# Plot data
ax.plot(K_values, AUPRC_values_LSTM, label='LSTM', linestyle='--', marker='x')
ax.plot(K_values, AUPRC_values_TCN, label='TCN', linestyle='--', marker='x')
ax.plot(K_values, AUPRC_values_LSTM_enc_dec, label='LSTM Enc-Dec', linestyle='--', marker='x')
ax.plot(K_values, AUPRC_values_LSTM_enc_dec_attn, label='LSTM Enc-Dec Attn', linestyle='--', marker='x')


plt.xticks(K_values)

# Add legend
ax.legend()

# Set x-label and y-label
plt.xlabel('K value (K = 1 represents 5 minutes)')
plt.ylabel('AUPRC')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
AUROC_values_TCN = [0.5207, 0.5319, 0.546, 0.565]
AUROC_values_LSTM = [0.53477, 0.5446, 0.5534, 0.5666]
AUROC_values_LSTM_enc_dec_attn = [0.548, 0.56, 0.5675, 0.58]
AUROC_values_LSTM_enc_dec = [0.5532, 0.559, 0.5645, 0.575]

# X-axis values
K_values = [6, 12, 24, 48]

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot data
ax.plot(K_values, AUROC_values_LSTM, label='LSTM', linestyle='--', marker='x')
ax.plot(K_values, AUROC_values_TCN, label='TCN', linestyle='--', marker='x')
ax.plot(K_values, AUROC_values_LSTM_enc_dec, label='LSTM Enc-Dec', linestyle='--', marker='x')
ax.plot(K_values, AUROC_values_LSTM_enc_dec_attn, label='LSTM Enc-Dec Attn', linestyle='--', marker='x')

# Set x-ticks
plt.xticks(K_values)

# Set x-label and y-label
plt.xlabel('K value, 5 mins sampling')
plt.ylabel('AUROC')

# Add legend
ax.legend()

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
precision = [0.36, 0.3409, 0.3205, 0.3]
specificity = [0.6298, 0.604, 0.5789, 0.5569]
sensitivity = [0.334, 0.2964, 0.278, 0.268]

# X-axis values
models = ['LSTM_enc_dec_attn, K = 48', 'LSTM_enc_dec_attn, K = 24', 'LSTM_enc_dec_attn, K = 12', 'LSTM_enc_dec_attn, K = 6']
x = np.arange(len(models))  # the label locations

# Width of the bars
width = 0.2

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Add bars
rects1 = ax.bar(x - width, precision, width, label='Precision')
rects2 = ax.bar(x, specificity, width, label='Specificity')
rects3 = ax.bar(x + width, sensitivity, width, label='Sensitivity')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Models')
ax.set_ylabel('Scores')
ax.set_title('Classification scores by model at cls. threshold = 0.5')
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=45)
ax.legend()

# Show plot
plt.show()
